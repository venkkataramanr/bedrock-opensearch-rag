# %% [markdown]
# ### Import modules

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection, AWSV4SignerAuth, helpers
import boto3
import json
import pandas as pd

# %% [markdown]
# ### Initialize and configure Boto Client for Bedrock

# %%
session = boto3.Session(profile_name="rapid-innovation-dev")
bedrock = session.client(
 service_name='bedrock-runtime',
 region_name='us-east-1',
#  endpoint_url='https://bedrock.us-east-1.amazonaws.com'
)

# %% [markdown]
# ### Initialize and configure OpenSearch client

# %%
with open('host.txt', 'r') as fp:
    host = fp.read()
region = "us-east-1"
service = "aoss"
credentials = session.get_credentials()
auth = AWSV4SignerAuth(credentials, region, service)

# %%
client = OpenSearch(
    hosts = [{"host": host, "port": 443}],
    http_auth = auth,
    use_ssl = True,
    verify_certs = True,
    connection_class = RequestsHttpConnection,
    pool_maxsize = 20
)

# %% [markdown]
# ### Process the dataset

# %%
df=pd.read_csv('./data/oscars.csv')

# %%
df=df.loc[df['year_ceremony'] == 2023]
df=df.dropna(subset=['film'])
df['category'] = df['category'].str.lower()

# %%
df.head()
# Out:
#        year_film  year_ceremony  ceremony                 category  \
# 10639       2022           2023        95  actor in a leading role
# 10640       2022           2023        95  actor in a leading role
# 10641       2022           2023        95  actor in a leading role
# 10642       2022           2023        95  actor in a leading role
# 10643       2022           2023        95  actor in a leading role
#
#                  name                       film  winner
# 10639   Austin Butler                      Elvis   False
# 10640   Colin Farrell  The Banshees of Inisherin   False
# 10641  Brendan Fraser                  The Whale    True
# 10642     Paul Mescal                   Aftersun   False
# 10643      Bill Nighy                     Living   False

# %% [markdown]
# ### Concatenate columns to create a new text colummn

# %%
# Create the column for all rows first
df['text'] = df['name'] + ' got nominated under the category, ' + df['category'] + ', for the film ' + df['film'] + ' to win the award'

# Find the rows where 'winner' is False and replace the 'text' for those rows
df.loc[df['winner'] == False, 'text'] = df['name'] + ' got nominated under the category, ' + df['category'] + ', for the film ' + df['film'] + ' but did not win'

# %%
df.head()
# Out:
#        year_film  year_ceremony  ceremony                 category  \
# 10639       2022           2023        95  actor in a leading role
# 10640       2022           2023        95  actor in a leading role
# 10641       2022           2023        95  actor in a leading role
# 10642       2022           2023        95  actor in a leading role
# 10643       2022           2023        95  actor in a leading role
#
#                  name                       film  winner  \
# 10639   Austin Butler                      Elvis   False
# 10640   Colin Farrell  The Banshees of Inisherin   False
# 10641  Brendan Fraser                  The Whale    True
# 10642     Paul Mescal                   Aftersun   False
# 10643      Bill Nighy                     Living   False
#
#                                                     text
# 10639  Austin Butler got nominated under the category...
# 10640  Colin Farrell got nominated under the category...
# 10641  Brendan Fraser got nominated under the categor...
# 10642  Paul Mescal got nominated under the category, ...
# 10643  Bill Nighy got nominated under the category, a...

# %% [markdown]
# ### Generate embeddings for the text column from Titan

# %%
def text_embedding(text):
    body=json.dumps({"inputText": text})
    response = bedrock.invoke_model(body=body, modelId='amazon.titan-embed-text-v1', accept='*/*', contentType='application/json')
    response_body = json.loads(response.get('body').read())
    embedding = response_body.get('embedding')
    return embedding

# %%
df=df.assign(embedding=(df["text"].apply(lambda x : text_embedding(x))))

# %%
pd.set_option('display.max_rows', 50)
df
# Out:
#        year_film  year_ceremony  ceremony                       category  \
# 10639       2022           2023        95        actor in a leading role
# 10640       2022           2023        95        actor in a leading role
# 10641       2022           2023        95        actor in a leading role
# 10642       2022           2023        95        actor in a leading role
# 10643       2022           2023        95        actor in a leading role
# ...          ...            ...       ...                            ...
# 10755       2022           2023        95  writing (original screenplay)
# 10756       2022           2023        95  writing (original screenplay)
# 10757       2022           2023        95  writing (original screenplay)
# 10758       2022           2023        95  writing (original screenplay)
# 10764       2022           2023        95          award of commendation
#
#                                                     name  \
# 10639                                      Austin Butler
# 10640                                      Colin Farrell
# 10641                                     Brendan Fraser
# 10642                                        Paul Mescal
# 10643                                         Bill Nighy
# ...                                                  ...
# 10755          Written by Daniel Kwan & Daniel Scheinert
# 10756         Written by Steven Spielberg & Tony Kushner
# 10757                              Written by Todd Field
# 10758                           Written by Ruben Östlund
# 10764  To Ryan Laney for his innovative adaptation an...
#
#                                     film  winner  \
# 10639                              Elvis   False
# 10640          The Banshees of Inisherin   False
# 10641                          The Whale    True
# 10642                           Aftersun   False
# 10643                             Living   False
# ...                                  ...     ...
# 10755  Everything Everywhere All at Once    True
# 10756                      The Fabelmans   False
# 10757                                Tár   False
# 10758                Triangle of Sadness   False
# 10764                Welcome to Chechnya    True
#
#                                                     text  \
# 10639  Austin Butler got nominated under the category...
# 10640  Colin Farrell got nominated under the category...
# 10641  Brendan Fraser got nominated under the categor...
# 10642  Paul Mescal got nominated under the category, ...
# 10643  Bill Nighy got nominated under the category, a...
# ...                                                  ...
# 10755  Written by Daniel Kwan & Daniel Scheinert got ...
# 10756  Written by Steven Spielberg & Tony Kushner got...
# 10757  Written by Todd Field got nominated under the ...
# 10758  Written by Ruben Östlund got nominated under t...
# 10764  To Ryan Laney for his innovative adaptation an...
#
#                                                embedding
# 10639  [-0.109375, -0.16601562, 0.25390625, -0.621093...
# 10640  [-0.46484375, -0.055664062, 0.23828125, -0.761...
# 10641  [0.26757812, -0.56640625, 0.22265625, -0.40429...
# 10642  [-0.43359375, 0.032714844, 0.28125, -0.5390625...
# 10643  [-0.43554688, -0.21289062, 0.18359375, -0.4335...
# ...                                                  ...
# 10755  [0.048583984, 0.038085938, 0.46484375, -0.5429...
# 10756  [-0.16503906, 0.029663086, 0.24414062, -0.7695...
# 10757  [-0.087890625, -0.114746094, 0.31835938, -0.66...
# 10758  [0.3046875, 0.07861328, 0.42773438, -0.4140625...
# 10764  [0.4140625, -0.31835938, 0.17382812, -0.154296...
#
# [121 rows x 9 columns]

# %% [markdown]
# ### Ingest the text and embeddings into AOSS

# %%
def add_document(vector,text):
    document = {
      "nominee_vector": vector,
      "nominee_text": text
    }
    
    response = client.index(
        index = 'oscars-index',
        body = document
    )
    print('\nAdding document:')
    print(response)

# %%
df.apply(lambda row: add_document(row['embedding'], row['text']), axis=1)
# Out:
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AnsOmJZABw5U0TIJo96gt', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Aj-GmJZABlACFB3AV-QGh', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3An8OmJZABw5U0TIJo_Kha', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AkOGmJZABlACFB3AV_gFM', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AoMOnJZABw5U0TIJoAKhR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AkeGnJZABlACFB3AVAgGg', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AocOnJZABw5U0TIJoBKi5', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AkuGnJZABlACFB3AVBwEl', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AosOnJZABw5U0TIJoCagF', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ak-GnJZABlACFB3AVCwEe', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ao8OnJZABw5U0TIJoDagK', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AlOGnJZABlACFB3AVDwGB', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ApMOnJZABw5U0TIJoEahn', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AleGnJZABlACFB3AVEwE0', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ApcOnJZABw5U0TIJoFaiI', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AluGnJZABlACFB3AVFwHq', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ApsOnJZABw5U0TIJoGajb', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Al-GnJZABlACFB3AVGwGo', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ap8OnJZABw5U0TIJoHaiC', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AmOGnJZABlACFB3AVHwHr', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AqMOnJZABw5U0TIJoIqhN', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AmeGnJZABlACFB3AVJAE2', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AqcOnJZABw5U0TIJoJqgL', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AmuGnJZABlACFB3AVJwH1', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AqsOnJZABw5U0TIJoKqhR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Am-GnJZABlACFB3AVLAGD', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Aq8OnJZABw5U0TIJoLqi3', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AnOGnJZABlACFB3AVMAGv', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ArMOnJZABw5U0TIJoM6gd', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AneGnJZABlACFB3AVNQEa', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ArcOnJZABw5U0TIJoN6gF', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AnuGnJZABlACFB3AVOQEI', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ArsOnJZABw5U0TIJoOqjw', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3An-GnJZABlACFB3AVPAHM', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ar8OnJZABw5U0TIJoP6gd', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AoOGnJZABlACFB3AVQQGF', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AsMOnJZABw5U0TIJoQ6h6', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AoeGnJZABlACFB3AVRQFi', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AscOnJZABw5U0TIJoR6hz', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AouGnJZABlACFB3AVSQGD', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AssOnJZABw5U0TIJoS6jE', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ao-GnJZABlACFB3AVTgEI', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3As8OnJZABw5U0TIJoUKgv', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ApOGnJZABlACFB3AVUgEa', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AtMOnJZABw5U0TIJoVKgA', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ApeGnJZABlACFB3AVVQHq', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AtcOnJZABw5U0TIJoWKhR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ApuGnJZABlACFB3AVWgE1', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AtsOnJZABw5U0TIJoXKhR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ap-GnJZABlACFB3AVXgEj', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3At8OnJZABw5U0TIJoYKgd', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AqOGnJZABlACFB3AVYQHs', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AuMOnJZABw5U0TIJoY6jK', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AqeGnJZABlACFB3AVZQGp', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AucOnJZABw5U0TIJoZ6iG', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AquGnJZABlACFB3AVaQFT', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AusOnJZABw5U0TIJoa6gx', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Aq-GnJZABlACFB3AVbQFQ', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Au8OnJZABw5U0TIJob6g2', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3ArOGnJZABlACFB3AVcQF3', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AvMOnJZABw5U0TIJoc6hL', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AreGnJZABlACFB3AVdQFh', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AvcOnJZABw5U0TIJod6gw', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AruGnJZABlACFB3AVeQEU', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AvsOnJZABw5U0TIJoeqj_', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ar-GnJZABlACFB3AVfQEh', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Av8OnJZABw5U0TIJof6gP', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AsOGnJZABlACFB3AVhAHI', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AwMOnJZABw5U0TIJoh6ix', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AseGnJZABlACFB3AViQG0', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AwcOnJZABw5U0TIJoi6ir', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AsuGnJZABlACFB3AVjQHp', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AwsOnJZABw5U0TIJoj6jV', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3As-GnJZABlACFB3AVkQGl', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Aw8OnJZABw5U0TIJok6jt', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AtOGnJZABlACFB3AVlgFO', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AxMOnJZABw5U0TIJomKi1', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AteGnJZABlACFB3AVmgGa', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AxcOnJZABw5U0TIJonKie', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AtuGnJZABlACFB3AVngG4', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AxsOnJZABw5U0TIJooKiv', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3At-GnJZABlACFB3AVogGF', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ax8OnJZABw5U0TIJopKiI', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AuOGnJZABlACFB3AVpgFf', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AyMOnJZABw5U0TIJoqKhc', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AueGnJZABlACFB3AVqgFS', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AycOnJZABw5U0TIJorKgg', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AuuGnJZABlACFB3AVrQHz', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AysOnJZABw5U0TIJor6jv', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Au-GnJZABlACFB3AVsQG1', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ay8OnJZABw5U0TIJos6iX', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AvOGnJZABlACFB3AVtQFe', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AzMOnJZABw5U0TIJot6h-', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AveGnJZABlACFB3AVuQFO', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AzcOnJZABw5U0TIJou6iE', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AvuGnJZABlACFB3AVvQGA', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AzsOnJZABw5U0TIJov6hv', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Av-GnJZABlACFB3AVwQFX', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Az8OnJZABw5U0TIJow6js', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AwOGnJZABlACFB3AVxgFN', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A0MOnJZABw5U0TIJoyKhP', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AweGnJZABlACFB3AVygEy', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A0cOnJZABw5U0TIJozKgb', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AwuGnJZABlACFB3AVzgFR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A0sOnJZABw5U0TIJo0Kga', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Aw-GnJZABlACFB3AV0gEe', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A08OnJZABw5U0TIJo06j8', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AxOGnJZABlACFB3AV1QHC', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A1MOnJZABw5U0TIJo16iN', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AxeGnJZABlACFB3AV2QGB', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A1cOnJZABw5U0TIJo26he', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AxuGnJZABlACFB3AV3QE6', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A1sOnJZABw5U0TIJo36hc', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3Ax-GnJZABlACFB3AV4QGR', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A18OnJZABw5U0TIJo46iG', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AyOGnJZABlACFB3AV5QFZ', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A2MOnJZABw5U0TIJo56hU', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AyeGnJZABlACFB3AV6QFs', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A2cOnJZABw5U0TIJo66hV', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3AyuGnJZABlACFB3AV7QE0', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
#
# Adding document:
# {'_index': 'oscars-index', '_id': '1%3A0%3A2sOnJZABw5U0TIJo76iF', '_version': 1, 'result': 'created', '_shards': {'total': 0, 'successful': 0, 'failed': 0}, '_seq_no': 0, '_primary_term': 0}
# 10639    None
# 10640    None
# 10641    None
# 10642    None
# 10643    None
#          ...
# 10755    None
# 10756    None
# 10757    None
# 10758    None
# 10764    None
# Length: 121, dtype: object

# %% [markdown]
# ### Perform semantic search

# %%
def search_index(vector):
    document = {
        "size": 15,
        "_source": {"excludes": ["nominee_vector"]},
        "query": {
            "knn": {
                 "nominee_vector": {
                     "vector": vector,
                     "k":15
                 }
            }
        }
    }
    response = client.search(
    body = document,
    index = "oscars-index"
    )
    return response

# %%
query='who won the award for best music?'
vector=text_embedding(query)

# %%
response=search_index(vector)
data=response['hits']['hits']

# %%
data
# Out:
# [{'_index': 'oscars-index',
#   '_id': '1%3A0%3Ar-GnJZABlACFB3AVfQEh',
#   '_score': 0.7270102,
#   '_source': {'nominee_text': 'Volker Bertelmann got nominated under the category, music (original score), for the film All Quiet on the Western Front to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3Av8OnJZABw5U0TIJof6gP',
#   '_score': 0.7232194,
#   '_source': {'nominee_text': 'Justin Hurwitz got nominated under the category, music (original score), for the film Babylon but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3As-GnJZABlACFB3AVkQGl',
#   '_score': 0.7190479,
#   '_source': {'nominee_text': 'Music by M.M. Keeravaani; Lyric by Chandrabose got nominated under the category, music (original song), for the film RRR to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AwsOnJZABw5U0TIJoj6jV',
#   '_score': 0.7148727,
#   '_source': {'nominee_text': 'Music by Tems, Rihanna, Ryan Coogler and Ludwig Goransson; Lyric by Tems and Ryan Coogler got nominated under the category, music (original song), for the film Black Panther: Wakanda Forever but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AwcOnJZABw5U0TIJoi6ir',
#   '_score': 0.71246034,
#   '_source': {'nominee_text': 'Music and Lyric by Diane Warren got nominated under the category, music (original song), for the film Tell It like a Woman but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AwMOnJZABw5U0TIJoh6ix',
#   '_score': 0.70840085,
#   '_source': {'nominee_text': 'Son Lux got nominated under the category, music (original score), for the film Everything Everywhere All at Once but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AsuGnJZABlACFB3AVjQHp',
#   '_score': 0.7004877,
#   '_source': {'nominee_text': 'Music and Lyric by Lady Gaga and BloodPop got nominated under the category, music (original song), for the film Top Gun: Maverick but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3Aw8OnJZABw5U0TIJok6jt',
#   '_score': 0.6990064,
#   '_source': {'nominee_text': 'Music by Ryan Lott, David Byrne and Mitski; Lyric by Ryan Lott and David Byrne got nominated under the category, music (original song), for the film Everything Everywhere All at Once but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3A0sOnJZABw5U0TIJo0Kga',
#   '_score': 0.68496835,
#   '_source': {'nominee_text': 'Mark Weingarten, James H. Mather, Al Nelson, Chris Burdon and Mark Taylor got nominated under the category, sound, for the film Top Gun: Maverick to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3A0MOnJZABw5U0TIJoyKhP',
#   '_score': 0.67821705,
#   '_source': {'nominee_text': 'Viktor Prášil, Frank Kruse, Markus Stemler, Lars Ginzel and Stefan Korte got nominated under the category, sound, for the film All Quiet on the Western Front but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AsOGnJZABlACFB3AVhAHI',
#   '_score': 0.6764615,
#   '_source': {'nominee_text': 'Carter Burwell got nominated under the category, music (original score), for the film The Banshees of Inisherin but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AsMOnJZABw5U0TIJoQ6h6',
#   '_score': 0.6725197,
#   '_source': {'nominee_text': 'Daniel Kwan and Daniel Scheinert got nominated under the category, directing, for the film Everything Everywhere All at Once to win the award'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AseGnJZABlACFB3AViQG0',
#   '_score': 0.6689026,
#   '_source': {'nominee_text': 'John Williams got nominated under the category, music (original score), for the film The Fabelmans but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3Aw-GnJZABlACFB3AV0gEe',
#   '_score': 0.66808057,
#   '_source': {'nominee_text': 'Frank Petzold, Viktor Müller, Markus Frank and Kamil Jafar got nominated under the category, visual effects, for the film All Quiet on the Western Front but did not win'}},
#  {'_index': 'oscars-index',
#   '_id': '1%3A0%3AwuGnJZABlACFB3AVzgFR',
#   '_score': 0.6669213,
#   '_source': {'nominee_text': 'David Lee, Wayne Pashley, Andy Nelson and Michael Keller got nominated under the category, sound, for the film Elvis but did not win'}}]
